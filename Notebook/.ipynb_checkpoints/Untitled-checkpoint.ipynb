# %% [markdown]
# #### IMPORTING LIBRARIES

# %%
# For Reading Data
import pandas as pd 
import numpy as np 
# For Data Visualization 
import matplotlib as plt 
import seaborn as sns

# %%
# importing utils
import sys

sys.path.append('..')
from utils.cleanning import CleanData
from utils.DataGroupby import advanced_groupby

# %% [markdown]
# #### READING DATA AN EXCEL FILE

# %%
df = pd.read_csv("E:/10 academy/Task/TellcoAnalysis/Data/Week1_challenge_data_source.csv")

# %%
df.head()
#this will print first five row of data
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311450e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311450e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311450e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311450e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311450e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI Last Location Name  \
# 0  1823652.0  2.082010e+14   3.366496e+10  3.552120e+13        9.16457E+15
# 1  1365104.0  2.082020e+14   3.368185e+10  3.579400e+13            L77566A
# 2  1361762.0  2.082000e+14   3.376063e+10  3.528150e+13            D42335A
# 3  1321509.0  2.082010e+14   3.375034e+10  3.535660e+13            T21824A
# 4  1089009.0  2.082010e+14   3.369980e+10  3.540700e+13            D88865A
#
#    ...  Youtube DL (Bytes)  Youtube UL (Bytes)  Netflix DL (Bytes)  \
# ...

# %% [markdown]
# #### DATA ANALYSIS

# %%
df.columns.tolist()
# Out:
# ['Bearer Id',
#  'Start',
#  'Start ms',
#  'End',
#  'End ms',
#  'Dur. (ms)',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Avg RTT DL (ms)',
#  'Avg RTT UL (ms)',
#  'Avg Bearer TP DL (kbps)',
#  'Avg Bearer TP UL (kbps)',
#  'TCP DL Retrans. Vol (Bytes)',
#  'TCP UL Retrans. Vol (Bytes)',
#  'DL TP < 50 Kbps (%)',
#  '50 Kbps < DL TP < 250 Kbps (%)',
#  '250 Kbps < DL TP < 1 Mbps (%)',
#  'DL TP > 1 Mbps (%)',
#  'UL TP < 10 Kbps (%)',
#  '10 Kbps < UL TP < 50 Kbps (%)',
#  '50 Kbps < UL TP < 300 Kbps (%)',
#  'UL TP > 300 Kbps (%)',
#  'HTTP DL (Bytes)',
#  'HTTP UL (Bytes)',
#  'Activity Duration DL (ms)',
#  'Activity Duration UL (ms)',
#  'Dur. (ms).1',
#  'Handset Manufacturer',
#  'Handset Type',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'Nb of sec with 6250B < Vol UL < 37500B',
# ...

# %%
df.shape
# Out:
# (150001, 55)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
df.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082017e+14
# std    2.893170e+18     288.611834     288.097653  8.103762e+04  2.149289e+10
# min    6.917540e+18       0.000000       0.000000  7.142000e+03  2.040470e+14
# 25%    7.349880e+18     250.000000     251.000000  5.744050e+04  2.082010e+14
# 50%    7.349880e+18     499.000000     500.000000  8.639900e+04  2.082020e+14
# 75%    1.304240e+19     749.000000     750.000000  1.324302e+05  2.082020e+14
# max    1.318650e+19     999.000000     999.000000  1.859336e+06  2.140740e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847454e+13       109.795706        17.662883
# ...

# %%
df.isna().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...

# %% [markdown]
# ##### cleaning the data and dealing with null values

# %%
# drop all rows with null values count less that 10
Dataset = CleanData(df)
Dataset.drop_rows(drop_in_columns=['Start','Start ms','End','End ms','Dur. (ms)','Avg Bearer TP DL (kbps)','Avg Bearer TP UL (kbps)','Activity Duration DL (ms)','Activity Duration UL (ms)','Total UL (Bytes)','Dur. (ms).1','Total DL (Bytes)'])
# Out:
# Automation in Action...!!!
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311450e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311450e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311450e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311450e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311450e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149995  1.304240e+19   4/29/2019 7:28     615.0   4/30/2019 0:01   407.0
# 149996  7.277830e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349880e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311450e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311450e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
# drop all rows with null that cant be replaced by mean
Dataset.drop_rows(drop_in_columns=['Bearer Id','IMSI','MSISDN/Number','IMEI','Last Location Name','Handset Manufacturer','Handset Type'])
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311450e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311450e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311450e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311450e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311450e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149995  1.304240e+19   4/29/2019 7:28     615.0   4/30/2019 0:01   407.0
# 149996  7.277830e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349880e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311450e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311450e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
# fill columns with mean with null less or about 1000
Dataset.fill_with_mean(fill_columns=['DL TP < 50 Kbps (%)','50 Kbps < DL TP < 250 Kbps (%)','250 Kbps < DL TP < 1 Mbps (%)','DL TP > 1 Mbps (%)','UL TP < 10 Kbps (%)','10 Kbps < UL TP < 50 Kbps (%)','50 Kbps < UL TP < 300 Kbps (%)','UL TP > 300 Kbps (%)','Nb of sec with Vol DL < 6250B','Nb of sec with Vol UL < 1250B'])

# additional fill with mean
Dataset.fill_with_mean(fill_columns=['Avg RTT DL (ms)','Avg RTT UL (ms)'])

# drop columns with more than 50% null
Dataset.drop_unwanted_column(unwanted_columns=['TCP DL Retrans. Vol (Bytes)','TCP UL Retrans. Vol (Bytes)',
                                            'HTTP DL (Bytes)','HTTP UL (Bytes)',
                                            ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8436/3892942339.py in <module>
#       6
#       7 # drop columns with more than 50% null
# ----> 8 Dataset.drop_unwanted_column(unwanted_columns=['TCP DL Retrans. Vol (Bytes)','TCP UL Retrans. Vol (Bytes)',
#       9                                             'HTTP DL (Bytes)','HTTP UL (Bytes)',
#      10                                             'Nb of sec with 125000B < Vol DL ' ,
#
# E:\10 academy\Task\TellcoAnalysis\Notebook\..\utils\cleanning.py in drop_unwanted_column(self, unwanted_columns)
#      56         def drop_unwanted_column(self, unwanted_columns)->pd.DataFrame:
#      57                 # drop columns in the list unwanted_columns
# ---> 58                 self.df.drop(unwanted_columns, axis=1, inplace=True)
#      59                 return self.df
#      60
#
# ...

# %%
Dataset.df.isna().sum()
# Out:
# Bearer Id                                        0
# Start                                            0
# Start ms                                         0
# End                                              0
# End ms                                           0
# Dur. (ms)                                        0
# IMSI                                             0
# MSISDN/Number                                    0
# IMEI                                             0
# Last Location Name                               0
# Avg RTT DL (ms)                                  0
# Avg RTT UL (ms)                                  0
# Avg Bearer TP DL (kbps)                          0
# Avg Bearer TP UL (kbps)                          0
# TCP DL Retrans. Vol (Bytes)                  87681
# TCP UL Retrans. Vol (Bytes)                  96029
# DL TP < 50 Kbps (%)                              0
# 50 Kbps < DL TP < 250 Kbps (%)                   0
# ...
